# %%
import pandas as pd

df_RRHH = pd.read_csv(R"C:\Users\marin\Desktop\Data Bootcamp\RRHH-26062025.csv", sep=';')
df_RRHH
# Out:
#       ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 0     14              11             11         2        4
# 1     36              13              4         4        3
# 2      9               6              7         3        1
# 3     28               9              7         3        1
# 4      9              12              3         3        2
# ...   ..             ...            ...       ...      ...
# 1105  22               1             10         4        4
# 1106  26              19              5         6        3
# 1107  34              19             12         3        4
# 1108  20              19              4         6        3
# 1109  14              10              5         2        3
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        155                       12            14   34
# 1                        118                       13            18   50
# 2                        228                       14            16   58
# 3                        225                       26             9   28
# 4                        228                       14            16   58
# ...                      ...                      ...           ...  ...
# 1105                     179                       26             9   30
# 1106                     300                       26            13   43
# 1107                     118                       10            10   37
# 1108                     260                       50            11   36
# 1109                     155                       12            14   34
#
#      Work_load_Average_day  ...  Disciplinary_failure  Education  Son  \
# 0                  284,031  ...                     0          1    2
# 1                  239,409  ...                     0          1    1
# 2                  264,604  ...                     0          1    2
# 3                  230,290  ...                     0          1    1
# 4                  222,196  ...                     0          1    2
# ...                    ...  ...                   ...        ...  ...
# 1105               265,017  ...                     0          3    0
# 1106               237,656  ...                     0          1    2
# 1107               261,306  ...                     0          1    0
# 1108               326,452  ...                     0          1    4
# 1109               237,656  ...                     0          1    2
#
#       Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0                  1              0    0      95     196               25
# 1                  1              0    0      98     178               31
# 2                  0              0    1      65     172               22
# 3                  0              0    2      69     169               24
# 4                  0              0    1      65     172               22
# ...              ...            ...  ...     ...     ...              ...
# 1105               0              0    0      56     171               19
# 1106               1              1    1      77     175               25
# 1107               0              0    0      83     172               28
# 1108               1              0    0      65     168               23
# 1109               1              0    0      95     196               25
#
#       Absenteeism_hours
# 0                   120
# 1                   120
# 2                   120
# 3                   112
# 4                   112
# ...                 ...
# 1105                 64
# 1106                 64
# 1107                 56
# 1108                 56
# 1109                 48
#
# [1110 rows x 21 columns]

# %%
duplicados_python = df_RRHH[df_RRHH.duplicated(keep=False)]
grupos_duplicados = duplicados_python.value_counts().reset_index().shape[0]
print(f"Grupos únicos de duplicados en Python: {grupos_duplicados}")
# Out:
# Grupos únicos de duplicados en Python: 41

# %%
duplicados_grouped = duplicados_python.value_counts().reset_index(name='repeticiones')
duplicados_grouped = duplicados_grouped.sort_values(by='Absenteeism_hours', ascending=False)

duplicados_grouped
# Out:
#     ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 6   14              11             11         2        4
# 5    9               6              7         3        1
# 9   36              13              4         4        3
# 10  28               9              7         3        1
# 7    9              12              3         3        2
# 16  11              19              3         2        3
# 18  13              13              7         2        1
# 40  36              13              6         4        3
# 20  14              18             12         3        2
# 34  34              19             12         3        4
# 22  22               1             10         4        4
# 27  26              19              5         6        3
# 33  34              19             12         3        4
# 21  20              19              4         6        3
# 17  14              10              5         2        3
# 15  10              22             12         4        4
# 0    3              27              2         4        2
# 2    3              27              3         5        2
# 31  28              23             12         4        4
# 26  22              23              5         4        3
# 8    3              27              2         6        2
# 36  34              23             10         3        4
# 3    3              27              3         4        2
# 4    3              27              2         4        2
# 1   22              27              4         6        3
# 35  34              27              1         2        2
# 23   5              23             10         2        4
# 19  15              28              5         5        3
# 13   3              27              2         6        2
# 12   3              23              7         6        1
# 11   3              27              2         2        2
# 14   3              27              2         5        2
# 25  22              27              5         6        3
# 38  34              27              1         4        2
# 37  34              27              1         3        2
# 29  27              23              1         5        2
# 28  24              28              7         3        1
# 39  34              27              1         5        2
# 24   3              28             12         6        4
# 32  24              28              9         3        1
# 30  28              23             11         4        4
#
#     Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 6                      155                       12            14   34
# 5                      228                       14            16   58
# 9                      118                       13            18   50
# 10                     225                       26             9   28
# 7                      228                       14            16   58
# 16                     289                       36            13   33
# 18                     369                       17            12   31
# 40                     118                       13            18   50
# 20                     155                       12            14   34
# 34                     118                       10            10   37
# 22                     179                       26             9   30
# 27                     300                       26            13   43
# 33                     118                       10            10   37
# 21                     260                       50            11   36
# 17                     155                       12            14   34
# 15                     361                       52             3   28
# 0                      179                       51            18   38
# 2                      179                       51            18   38
# 31                     225                       26             9   28
# 26                     179                       26             9   30
# 8                      179                       51            18   38
# 36                     118                       10            10   37
# 3                      179                       51            18   38
# 4                      179                       51            18   38
# 1                      179                       26             9   30
# 35                     118                       10            10   37
# 23                     235                       20            13   43
# 19                     291                       31            12   40
# 13                     179                       51            18   38
# 12                     179                       51            18   38
# 11                     179                       51            18   38
# 14                     179                       51            18   38
# 25                     179                       26             9   30
# 38                     118                       10            10   37
# 37                     118                       10            10   37
# 29                     184                       42             7   27
# 28                     246                       25            16   41
# 39                     118                       10            10   37
# 24                     179                       51            18   38
# 32                     246                       25            16   41
# 30                     225                       26             9   28
#
#    Work_load_Average_day  ...  Education  Son  Social_drinker  Social_smoker  \
# 6                284,031  ...          1    2               1              0
# 5                264,604  ...          1    2               0              0
# 9                239,409  ...          1    1               1              0
# 10               230,290  ...          1    1               0              0
# 7                222,196  ...          1    2               0              0
# 16               222,196  ...          1    2               1              0
# 18               264,604  ...          1    3               1              0
# 40               377,550  ...          1    1               1              0
# 20               280,549  ...          1    2               1              0
# 34               261,306  ...          1    0               0              0
# 22               265,017  ...          3    0               0              0
# 27               237,656  ...          1    2               1              1
# 33               261,306  ...          1    0               0              0
# 21               326,452  ...          1    4               1              0
# 17               237,656  ...          1    2               1              0
# 15               261,306  ...          1    1               1              0
# 0                251,818  ...          1    0               1              0
# 2                222,196  ...          1    0               1              0
# 31               280,549  ...          1    1               0              0
# 26               246,074  ...          3    0               0              0
# 8                251,818  ...          1    0               1              0
# 36               253,465  ...          1    0               0              0
# 3                222,196  ...          1    0               1              0
# 4                264,249  ...          1    0               1              0
# 1                246,288  ...          3    0               0              0
# 35               308,593  ...          1    0               0              0
# 23               265,017  ...          1    1               1              0
# 19               237,656  ...          1    1               1              0
# 13               264,249  ...          1    0               1              0
# 12               239,554  ...          1    0               1              0
# 11               264,249  ...          1    0               1              0
# 14               264,249  ...          1    0               1              0
# 25               237,656  ...          3    0               0              0
# 38               308,593  ...          1    0               0              0
# 37               308,593  ...          1    0               0              0
# 29               308,593  ...          1    0               0              0
# 28               230,290  ...          1    0               1              0
# 39               308,593  ...          1    0               0              0
# 24               236,629  ...          1    0               1              0
# 32               261,756  ...          1    0               1              0
# 30               306,345  ...          1    1               0              0
#
#     Pet  Weight  Height  Body_mass_index  Absenteeism_hours  repeticiones
# 6     0      95     196               25                120             3
# 5     1      65     172               22                120             3
# 9     0      98     178               31                120             3
# 10    2      69     169               24                112             3
# 7     1      65     172               22                112             3
# 16    1      90     172               30                104             2
# 18    0      70     169               25                 80             2
# 40    0      98     178               31                 80             2
# 20    0      95     196               25                 80             2
# 34    0      83     172               28                 64             2
# 22    0      56     171               19                 64             2
# 27    1      77     175               25                 64             2
# 33    0      83     172               28                 56             2
# 21    0      65     168               23                 56             2
# 17    0      95     196               25                 48             2
# 15    4      80     172               27                  8             2
# 0     0      89     170               31                  3             4
# 2     0      89     170               31                  3             3
# 31    2      69     169               24                  3             2
# 26    0      56     171               19                  3             2
# 8     0      89     170               31                  3             3
# 36    0      83     172               28                  3             2
# 3     0      89     170               31                  2             3
# 4     0      89     170               31                  2             3
# 1     0      56     171               19                  2             4
# 35    0      83     172               28                  2             2
# 23    0     106     167               38                  2             2
# 19    1      73     171               25                  2             2
# 13    0      89     170               31                  2             2
# 12    0      89     170               31                  2             2
# 11    0      89     170               31                  2             2
# 14    0      89     170               31                  2             2
# 25    0      56     171               19                  2             2
# 38    0      83     172               28                  2             2
# 37    0      83     172               28                  2             2
# 29    0      58     167               21                  2             2
# 28    0      67     170               23                  2             2
# 39    0      83     172               28                  2             2
# 24    0      89     170               31                  1             2
# 32    0      67     170               23                  1             2
# 30    2      69     169               24                  1             2
#
# [41 rows x 22 columns]

# %%
key_fields = ['ID', 'Reason_absence', 'Month_absence', 'Day_week']

repeticiones = duplicados_grouped.groupby(key_fields).agg(
    veces=('ID', 'count'),
    horas_totales=('Absenteeism_hours', 'sum'),
 ).reset_index()

repeticiones.sort_values(["horas_totales"],ascending=False)
# Out:
#     ID  Reason_absence  Month_absence  Day_week  veces  horas_totales
# 15  14              11             11         2      1            120
# 9    9               6              7         3      1            120
# 36  36              13              4         4      1            120
# 30  34              19             12         3      2            120
# 27  28               9              7         3      1            112
# 10   9              12              3         3      1            112
# 12  11              19              3         2      1            104
# 13  13              13              7         2      1             80
# 37  36              13              6         4      1             80
# 16  14              18             12         3      1             80
# 19  22               1             10         4      1             64
# 25  26              19              5         6      1             64
# 18  20              19              4         6      1             56
# 14  14              10              5         2      1             48
# 11  10              22             12         4      1              8
# 4    3              27              2         6      2              5
# 2    3              27              2         4      2              5
# 6    3              27              3         5      1              3
# 20  22              23              5         4      1              3
# 31  34              23             10         3      1              3
# 29  28              23             12         4      1              3
# 1    3              27              2         2      1              2
# 5    3              27              3         4      1              2
# 3    3              27              2         5      1              2
# 0    3              23              7         6      1              2
# 17  15              28              5         5      1              2
# 33  34              27              1         3      1              2
# 21  22              27              4         6      1              2
# 8    5              23             10         2      1              2
# 22  22              27              5         6      1              2
# 35  34              27              1         5      1              2
# 32  34              27              1         2      1              2
# 23  24              28              7         3      1              2
# 26  27              23              1         5      1              2
# 34  34              27              1         4      1              2
# 7    3              28             12         6      1              1
# 28  28              23             11         4      1              1
# 24  24              28              9         3      1              1

# %%
repeticiones_sospechosas = repeticiones[repeticiones['horas_totales'] > 40]
repeticiones_sospechosas
# Out:
#     ID  Reason_absence  Month_absence  Day_week  veces  horas_totales
# 9    9               6              7         3      1            120
# 10   9              12              3         3      1            112
# 12  11              19              3         2      1            104
# 13  13              13              7         2      1             80
# 14  14              10              5         2      1             48
# 15  14              11             11         2      1            120
# 16  14              18             12         3      1             80
# 18  20              19              4         6      1             56
# 19  22               1             10         4      1             64
# 25  26              19              5         6      1             64
# 27  28               9              7         3      1            112
# 30  34              19             12         3      2            120
# 36  36              13              4         4      1            120
# 37  36              13              6         4      1             80

# %% [markdown]
# ## Eliminamos duplicados sospechosos

# %%
df_flagged = df_RRHH.merge(
    repeticiones_sospechosas[key_fields],
    how='left',
    on=key_fields,
    indicator=True
)

df_flagged
# Out:
#       ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 0     14              11             11         2        4
# 1     36              13              4         4        3
# 2      9               6              7         3        1
# 3     28               9              7         3        1
# 4      9              12              3         3        2
# ...   ..             ...            ...       ...      ...
# 1105  22               1             10         4        4
# 1106  26              19              5         6        3
# 1107  34              19             12         3        4
# 1108  20              19              4         6        3
# 1109  14              10              5         2        3
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        155                       12            14   34
# 1                        118                       13            18   50
# 2                        228                       14            16   58
# 3                        225                       26             9   28
# 4                        228                       14            16   58
# ...                      ...                      ...           ...  ...
# 1105                     179                       26             9   30
# 1106                     300                       26            13   43
# 1107                     118                       10            10   37
# 1108                     260                       50            11   36
# 1109                     155                       12            14   34
#
#      Work_load_Average_day  ...  Education  Son  Social_drinker  \
# 0                  284,031  ...          1    2               1
# 1                  239,409  ...          1    1               1
# 2                  264,604  ...          1    2               0
# 3                  230,290  ...          1    1               0
# 4                  222,196  ...          1    2               0
# ...                    ...  ...        ...  ...             ...
# 1105               265,017  ...          3    0               0
# 1106               237,656  ...          1    2               1
# 1107               261,306  ...          1    0               0
# 1108               326,452  ...          1    4               1
# 1109               237,656  ...          1    2               1
#
#       Social_smoker  Pet  Weight  Height  Body_mass_index  Absenteeism_hours  \
# 0                 0    0      95     196               25                120
# 1                 0    0      98     178               31                120
# 2                 0    1      65     172               22                120
# 3                 0    2      69     169               24                112
# 4                 0    1      65     172               22                112
# ...             ...  ...     ...     ...              ...                ...
# 1105              0    0      56     171               19                 64
# 1106              1    1      77     175               25                 64
# 1107              0    0      83     172               28                 56
# 1108              0    0      65     168               23                 56
# 1109              0    0      95     196               25                 48
#
#       _merge
# 0       both
# 1       both
# 2       both
# 3       both
# 4       both
# ...      ...
# 1105    both
# 1106    both
# 1107    both
# 1108    both
# 1109    both
#
# [1110 rows x 22 columns]

# %%
sospechosos = df_flagged[df_flagged['_merge'] == 'both']
no_sospechosos = df_flagged[df_flagged['_merge'] == 'left_only']
sospechosos_unique = sospechosos.groupby(key_fields).head(1)
df_RRHH_clean = pd.concat([no_sospechosos, sospechosos_unique]).drop(columns=['_merge']).reset_index(drop=True)
df_RRHH_clean
# Out:
#       ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 0     14              19              7         2        1
# 1     10              13              8         2        1
# 2     15              14             11         2        4
# 3     20              13              3         6        2
# 4     17              11              3         2        2
# ...   ..             ...            ...       ...      ...
# 1082  34              19             12         3        4
# 1083  22               1             10         4        4
# 1084  26              19              5         6        3
# 1085  20              19              4         6        3
# 1086  14              10              5         2        3
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        155                       12            14   34
# 1                        361                       52             3   28
# 2                        291                       31            12   40
# 3                        260                       50            11   36
# 4                        179                       22            17   40
# ...                      ...                      ...           ...  ...
# 1082                     118                       10            10   37
# 1083                     179                       26             9   30
# 1084                     300                       26            13   43
# 1085                     260                       50            11   36
# 1086                     155                       12            14   34
#
#      Work_load_Average_day  ...  Disciplinary_failure  Education  Son  \
# 0                  239,554  ...                     0          1    2
# 1                  205,917  ...                     0          1    1
# 2                  306,345  ...                     0          1    1
# 3                  343,253  ...                     0          1    4
# 4                  343,253  ...                     0          2    2
# ...                    ...  ...                   ...        ...  ...
# 1082               261,306  ...                     0          1    0
# 1083               265,017  ...                     0          3    0
# 1084               237,656  ...                     0          1    2
# 1085               326,452  ...                     0          1    4
# 1086               237,656  ...                     0          1    2
#
#       Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0                  1              0    0      95     196               25
# 1                  1              0    4      80     172               27
# 2                  1              0    1      73     171               25
# 3                  1              0    0      65     168               23
# 4                  0              1    0      63     170               22
# ...              ...            ...  ...     ...     ...              ...
# 1082               0              0    0      83     172               28
# 1083               0              0    0      56     171               19
# 1084               1              1    1      77     175               25
# 1085               1              0    0      65     168               23
# 1086               1              0    0      95     196               25
#
#       Absenteeism_hours
# 0                    40
# 1                    40
# 2                    40
# 3                    40
# 4                    40
# ...                 ...
# 1082                 64
# 1083                 64
# 1084                 64
# 1085                 56
# 1086                 48
#
# [1087 rows x 21 columns]

# %% [markdown]
# # Chequeamos tipos de datos

# %%
df_RRHH_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1087 non-null   int64
#  1   Reason_absence           1087 non-null   int64
#  2   Month_absence            1087 non-null   int64
#  3   Day_week                 1087 non-null   int64
#  4   Seasons                  1087 non-null   int64
#  5   Transportation_expense   1087 non-null   int64
#  6   Distance_Residence_Work  1087 non-null   int64
#  7   Service_time             1087 non-null   int64
#  8   Age                      1087 non-null   int64
#  9   Work_load_Average_day    1087 non-null   object
#  10  Hit_target               1087 non-null   int64
#  11  Disciplinary_failure     1087 non-null   int64
#  12  Education                1087 non-null   int64
#  13  Son                      1087 non-null   int64
#  14  Social_drinker           1087 non-null   int64
#  15  Social_smoker            1087 non-null   int64
#  16  Pet                      1087 non-null   int64
#  17  Weight                   1087 non-null   int64
#  18  Height                   1087 non-null   int64
#  19  Body_mass_index          1087 non-null   int64
#  20  Absenteeism_hours        1087 non-null   int64
# dtypes: int64(20), object(1)
# memory usage: 178.5+ KB

# %%
print(df_RRHH_clean['Work_load_Average_day'].unique()[:10])
# Out:
# [239.554 205.917 306.345 343.253 294.217 253.957 241.476 275.312 330.061
#  280.549]

# %%
df_RRHH_clean['Work_load_Average_day'] = df_RRHH_clean['Work_load_Average_day'].str.replace(',', '.')
df_RRHH_clean['Work_load_Average_day'] = df_RRHH_clean['Work_load_Average_day'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_RRHH_clean['Work_load_Average_day'] = df_RRHH_clean['Work_load_Average_day'].str.replace(',', '.')
#       2 df_RRHH_clean['Work_load_Average_day'] = df_RRHH_clean['Work_load_Average_day'].astype(float)
#
# File c:\Users\marin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Users\marin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\marin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\marin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# # Exportamos el fichero limpio

# %%
df_RRHH_clean.to_csv("RRHH - 26062025.csv", index=False)

# %%
df_RRHH_clean
# Out:
#       ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 0     14              19              7         2        1
# 1     10              13              8         2        1
# 2     15              14             11         2        4
# 3     20              13              3         6        2
# 4     17              11              3         2        2
# ...   ..             ...            ...       ...      ...
# 1082  34              19             12         3        4
# 1083  22               1             10         4        4
# 1084  26              19              5         6        3
# 1085  20              19              4         6        3
# 1086  14              10              5         2        3
#
#       Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                        155                       12            14   34
# 1                        361                       52             3   28
# 2                        291                       31            12   40
# 3                        260                       50            11   36
# 4                        179                       22            17   40
# ...                      ...                      ...           ...  ...
# 1082                     118                       10            10   37
# 1083                     179                       26             9   30
# 1084                     300                       26            13   43
# 1085                     260                       50            11   36
# 1086                     155                       12            14   34
#
#       Work_load_Average_day  ...  Disciplinary_failure  Education  Son  \
# 0                   239.554  ...                     0          1    2
# 1                   205.917  ...                     0          1    1
# 2                   306.345  ...                     0          1    1
# 3                   343.253  ...                     0          1    4
# 4                   343.253  ...                     0          2    2
# ...                     ...  ...                   ...        ...  ...
# 1082                261.306  ...                     0          1    0
# 1083                265.017  ...                     0          3    0
# 1084                237.656  ...                     0          1    2
# 1085                326.452  ...                     0          1    4
# 1086                237.656  ...                     0          1    2
#
#       Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0                  1              0    0      95     196               25
# 1                  1              0    4      80     172               27
# 2                  1              0    1      73     171               25
# 3                  1              0    0      65     168               23
# 4                  0              1    0      63     170               22
# ...              ...            ...  ...     ...     ...              ...
# 1082               0              0    0      83     172               28
# 1083               0              0    0      56     171               19
# 1084               1              1    1      77     175               25
# 1085               1              0    0      65     168               23
# 1086               1              0    0      95     196               25
#
#       Absenteeism_hours
# 0                    40
# 1                    40
# 2                    40
# 3                    40
# 4                    40
# ...                 ...
# 1082                 64
# 1083                 64
# 1084                 64
# 1085                 56
# 1086                 48
#
# [1087 rows x 21 columns]

# %% [markdown]
# # Calculamos numeros para verificar con Veronica

# %%
duplicate_rows = df_RRHH_clean[df_RRHH_clean.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
# Out:
# Number of duplicate rows: 34

# %%
total_registros = len(df_RRHH)
print(f"Total de registros: {total_registros}")
# Out:
# Total de registros: 1110

# %%
duplicados_id = df_RRHH.duplicated(subset='ID').sum()
print(f"Duplicados por ID: {duplicados_id}")
# Out:
# Duplicados por ID: 724

# %%
ids_unicos = df_RRHH['ID'].nunique()
print(f"IDs únicos: {ids_unicos}")
# Out:
# IDs únicos: 386
