# %% [markdown]
# ### EAL-24f. EMPRESAS DEL SECTOR SERVICIOS QUE PROPORCIONARON FORMACIÓN A SUS TRABAJADORES, SEGÚN GRADO DE LIMITACIÓN A LA FORMACIÓN  QUE SUPUSIERON CIERTOS MOTIVOS

# %%
import pandas as pd
from pathlib import Path

carpeta_excels = Path.home() / "Escritorio" / "excels_EAL"
datos_combinados = []

for archivo in carpeta_excels.glob("*.xls*"):
    if archivo.name.startswith("~$"):
        continue
    try:
        if archivo.name == "Tablas_EAL_2023.xlsx":
            df = pd.read_excel(archivo, sheet_name="EAL-24", header=None,
                               engine="openpyxl" if archivo.suffix == ".xlsx" else None)
            df_recorte = pd.concat([df.iloc[98:103], df.iloc[104:107]], ignore_index=True)
        elif archivo.name in ["Tablas_EAL_2022.xlsx", "TABLAS_EAL_2021.xlsx"]:
            df = pd.read_excel(archivo, sheet_name="EAL-24", header=None,
                               engine="openpyxl" if archivo.suffix == ".xlsx" else None)
            df_recorte = df.iloc[92:101].copy()
        elif archivo.name == "TABLAS_EAL_2020.xls":
            df = pd.read_excel(archivo, sheet_name="EAL-24", header=None,
                               engine="openpyxl" if archivo.suffix == ".xlsx" else None)
            df_recorte = df.iloc[90:99].copy()
        elif archivo.name in ["TABLAS_EAL_2019.xlsx", "TABLAS_EAL_2019.xls"]:
            df = pd.read_excel(archivo, sheet_name="EAL-24", header=None,
                               engine="openpyxl" if archivo.suffix == ".xlsx" else None)
            df_recorte = df.iloc[91:100].copy()
        else:
            continue
        df_recorte["Fuente"] = archivo.stem
        datos_combinados.append(df_recorte)
        print(f"✅ Filas extraídas de {archivo.name}")
    except Exception as e:
        print(f"❌ Error con {archivo.name}: {e}")

# Combinar todos los DataFrames
df_final = pd.concat(datos_combinados, ignore_index=True)

# Mostrar una muestra
print("\n🧾 Muestra del DataFrame combinado:")
print(df_final.head())
# Out:
# ✅ Filas extraídas de TABLAS_EAL_2019.xls
# ✅ Filas extraídas de TABLAS_EAL_2020.xls
# ✅ Filas extraídas de TABLAS_EAL_2021.xlsx
# ✅ Filas extraídas de Tablas_EAL_2022.xlsx
# ✅ Filas extraídas de Tablas_EAL_2023.xlsx
#
# 🧾 Muestra del DataFrame combinado:
#                                                    0    1       2       3  \
# 0  El nivel de formación de los empleados era el ...  100  13.179  28.546
# 1  La estrategia preferida de la empresa fue cont...  100  24.645  29.041
# 2  Dificultad para evaluar la necesidades de form...  100  30.468  54.968
# 3  La falta de cursos de formación adecuados en e...  100  25.501   46.19
# 4           El alto coste de los cursos de formación  100  19.927  34.443
#
#         4       5           Fuente
# 0  45.004  13.271  TABLAS_EAL_2019
# 1  35.761  10.553  TABLAS_EAL_2019
# 2  12.985   1.579  TABLAS_EAL_2019
# 3  22.068    6.24  TABLAS_EAL_2019
# 4  32.569  13.061  TABLAS_EAL_2019

# %%
# Renombrar las columnas 0 a 5
df_final.rename(columns={
    0: 'motivo',
    1: 'total',
    2: 'nada',
    3: 'poco',
    4: 'bastante',
    5: 'mucho'
}, inplace=True)

# Mostrar

# %%
# 1. Cambiar el nombre de la última columna 'Fuente' por 'año'
df_final.rename(columns={df_final.columns[-1]: 'año'}, inplace=True)

# 2. Quedarte solo con los 4 últimos caracteres de cada registro en la columna 'año'
df_final['año'] = df_final['año'].astype(str).str[-4:]

# Mostrar el resultado
df_final.head()
# Out:
#                                               motivo total    nada    poco  \
# 0  El nivel de formación de los empleados era el ...   100  13.179  28.546
# 1  La estrategia preferida de la empresa fue cont...   100  24.645  29.041
# 2  Dificultad para evaluar la necesidades de form...   100  30.468  54.968
# 3  La falta de cursos de formación adecuados en e...   100  25.501   46.19
# 4           El alto coste de los cursos de formación   100  19.927  34.443
#
#   bastante   mucho   año
# 0   45.004  13.271  2019
# 1   35.761  10.553  2019
# 2   12.985   1.579  2019
# 3   22.068    6.24  2019
# 4   32.569  13.061  2019

# %%
df_final['motivo'] = df_final['motivo'].str.strip()
df_final['motivo'] = df_final['motivo'].replace(
    "La empresa prefirió contratar a personal con la cualificación, habilidades y competencias necesarias",
    "La estrategia preferida de la empresa fue contratar personal con la cualificación, habilidades o competencias requeridas"
)

df_final
# Out:
#                                                motivo total    nada    poco  \
# 0   El nivel de formación de los empleados era el ...   100  13.179  28.546
# 1   La estrategia preferida de la empresa fue cont...   100  24.645  29.041
# 2   Dificultad para evaluar la necesidades de form...   100  30.468  54.968
# 3   La falta de cursos de formación adecuados en e...   100  25.501   46.19
# 4            El alto coste de los cursos de formación   100  19.927  34.443
# 5   El mayor esfuerzo realizado en años anteriores...   100  25.855  49.753
# 6   La elevada carga de trabajo y el escaso tiempo...   100  10.804  26.158
# 7   Dificultad para acceder a ayudas o subvencione...   100   19.13  36.743
# 8   El nivel de formación de los empleados era el ...   100  10.567  12.991
# 9   La estrategia preferida de la empresa fue cont...   100  34.293  20.911
# 10  Dificultad para evaluar la necesidades de form...   100  38.287   42.99
# 11  La falta de cursos de formación adecuados en e...   100  32.089  38.983
# 12           El alto coste de los cursos de formación   100  23.941  35.758
# 13  El mayor esfuerzo realizado en años anteriores...   100  38.941  35.043
# 14  La elevada carga de trabajo y el escaso tiempo...   100  19.443  27.808
# 15  Dificultad para acceder a ayudas o subvencione...   100  28.305  34.171
# 16  El nivel de formación de los empleados era el ...   100   8.612  21.465
# 17  La estrategia preferida de la empresa fue cont...   100  22.605  28.778
# 18  Dificultad para evaluar la necesidades de form...   100  31.225  50.796
# 19  La falta de cursos de formación adecuados en e...   100  30.153  42.341
# 20           El alto coste de los cursos de formación   100  22.367  37.502
# 21  El mayor esfuerzo realizado en años anteriores...   100  32.675  41.653
# 22  La elevada carga de trabajo y el escaso tiempo...   100  15.853  31.207
# 23  Dificultad para acceder a ayudas o subvencione...   100  23.134  37.848
# 24  El nivel de formación de los empleados era el ...   100   6.804  18.486
# 25  La estrategia preferida de la empresa fue cont...   100   17.78  27.601
# 26  Dificultad para evaluar la necesidades de form...   100  25.574  57.645
# 27  La falta de cursos de formación adecuados en e...   100   22.54  47.566
# 28           El alto coste de los cursos de formación   100  16.508  39.008
# 29  El mayor esfuerzo realizado en años anteriores...   100  27.979  42.148
# 30  La elevada carga de trabajo y el escaso tiempo...   100  11.869   32.02
# 31  Dificultad para acceder a ayudas o subvencione...   100  19.474  38.007
# 32  El nivel de formación de los empleados era el ...   100   8.198  17.574
# 33  La estrategia preferida de la empresa fue cont...   100  20.622  25.614
# 34  Dificultad para evaluar la necesidades de form...   100  28.524  54.054
# 35  La falta de cursos de formación adecuados en e...   100  25.199  46.846
# 36           El alto coste de los cursos de formación   100  19.205  39.063
# 37  El mayor esfuerzo realizado en años anteriores...   100  27.157  43.202
# 38  La elevada carga de trabajo y el escaso tiempo...   100  12.425  31.689
# 39  Dificultad para acceder a ayudas o subvencione...   100  20.418  38.416
#
#    bastante   mucho   año
# 0    45.004  13.271  2019
# 1    35.761  10.553  2019
# 2    12.985   1.579  2019
# 3    22.068    6.24  2019
# 4    32.569  13.061  2019
# 5    21.126   3.266  2019
# 6    42.043  20.995  2019
# 7     28.97  15.156  2019
# 8    61.078  15.364  2020
# 9    35.687   9.109  2020
# 10   16.888   1.836  2020
# 11    21.95   6.978  2020
# 12   30.057  10.244  2020
# 13   23.438   2.578  2020
# 14   39.344  13.405  2020
# 15   25.868  11.656  2020
# 16   52.856  17.067  2021
# 17   36.853  11.764  2021
# 18   16.154   1.825  2021
# 19   21.571   5.935  2021
# 20    29.94  10.191  2021
# 21   22.613   3.058  2021
# 22   39.375  13.566  2021
# 23   28.331  10.687  2021
# 24   58.857  15.853  2022
# 25   43.014  11.605  2022
# 26   14.513   2.268  2022
# 27   23.787   6.107  2022
# 28   32.701  11.783  2022
# 29   27.487   2.386  2022
# 30   41.547  14.565  2022
# 31    30.02  12.499  2022
# 32    56.83  17.398  2023
# 33   41.983  11.781  2023
# 34   15.397   2.025  2023
# 35   21.676    6.28  2023
# 36   30.317  11.415  2023
# 37   26.888   2.753  2023
# 38   39.563  16.323  2023
# 39   28.291  12.876  2023

# %%
# Reemplazar los valores de la columna 'motivo' según lo solicitado
df_final['motivo'] = df_final['motivo'].replace({
    "El nivel de formación de los empleados era el apropiado para las necesidades de la empresa": "nivel formación apropiado",
    "La estrategia preferida de la empresa fue contratar personal con la cualificación, habilidades o competencias requeridas": "contratar personal cualificado",
    "Dificultad para evaluar la necesidades de formación de la empresa": "evaluar necesidades",
    "La falta de cursos de formación adecuados en el mercado": "falta de cursos adecuados",
    "El alto coste de los cursos de formación": "alto coste cursos",
    "El mayor esfuerzo realizado en años anteriores para ofrecer formación a sus trabajadores": "esfuerzo realizado",
    "La elevada carga de trabajo y el escaso tiempo disponible de los empleados de su empresa": "carga de trabajo y el escaso tiempo",
    "Dificultad para acceder a ayudas o subvenciones públicas": "acceder a ayudas o subvenciones"
})

# %%
# Crear una columna 'numero de motivo' que enumere del 1 al 8 para cada motivo
motivos_unicos = df_final['motivo'].unique()
motivo_dict = {motivo: i+1 for i, motivo in enumerate(motivos_unicos)}
df_final['numero_motivo'] = df_final['motivo'].map(motivo_dict)

# Mostrar para comprobar
print(df_final[['motivo', 'numero_motivo']].drop_duplicates())

df_final
# Out:
#                                 motivo  numero_motivo
# 0            nivel formación apropiado              1
# 1       contratar personal cualificado              2
# 2                  evaluar necesidades              3
# 3            falta de cursos adecuados              4
# 4                    alto coste cursos              5
# 5                   esfuerzo realizado              6
# 6  carga de trabajo y el escaso tiempo              7
# 7      acceder a ayudas o subvenciones              8
#                                  motivo total    nada    poco bastante  \
# 0             nivel formación apropiado   100  13.179  28.546   45.004
# 1        contratar personal cualificado   100  24.645  29.041   35.761
# 2                   evaluar necesidades   100  30.468  54.968   12.985
# 3             falta de cursos adecuados   100  25.501   46.19   22.068
# 4                     alto coste cursos   100  19.927  34.443   32.569
# 5                    esfuerzo realizado   100  25.855  49.753   21.126
# 6   carga de trabajo y el escaso tiempo   100  10.804  26.158   42.043
# 7       acceder a ayudas o subvenciones   100   19.13  36.743    28.97
# 8             nivel formación apropiado   100  10.567  12.991   61.078
# 9        contratar personal cualificado   100  34.293  20.911   35.687
# 10                  evaluar necesidades   100  38.287   42.99   16.888
# 11            falta de cursos adecuados   100  32.089  38.983    21.95
# 12                    alto coste cursos   100  23.941  35.758   30.057
# 13                   esfuerzo realizado   100  38.941  35.043   23.438
# 14  carga de trabajo y el escaso tiempo   100  19.443  27.808   39.344
# 15      acceder a ayudas o subvenciones   100  28.305  34.171   25.868
# 16            nivel formación apropiado   100   8.612  21.465   52.856
# 17       contratar personal cualificado   100  22.605  28.778   36.853
# 18                  evaluar necesidades   100  31.225  50.796   16.154
# 19            falta de cursos adecuados   100  30.153  42.341   21.571
# 20                    alto coste cursos   100  22.367  37.502    29.94
# 21                   esfuerzo realizado   100  32.675  41.653   22.613
# 22  carga de trabajo y el escaso tiempo   100  15.853  31.207   39.375
# 23      acceder a ayudas o subvenciones   100  23.134  37.848   28.331
# 24            nivel formación apropiado   100   6.804  18.486   58.857
# 25       contratar personal cualificado   100   17.78  27.601   43.014
# 26                  evaluar necesidades   100  25.574  57.645   14.513
# 27            falta de cursos adecuados   100   22.54  47.566   23.787
# 28                    alto coste cursos   100  16.508  39.008   32.701
# 29                   esfuerzo realizado   100  27.979  42.148   27.487
# 30  carga de trabajo y el escaso tiempo   100  11.869   32.02   41.547
# 31      acceder a ayudas o subvenciones   100  19.474  38.007    30.02
# 32            nivel formación apropiado   100   8.198  17.574    56.83
# 33       contratar personal cualificado   100  20.622  25.614   41.983
# 34                  evaluar necesidades   100  28.524  54.054   15.397
# 35            falta de cursos adecuados   100  25.199  46.846   21.676
# 36                    alto coste cursos   100  19.205  39.063   30.317
# 37                   esfuerzo realizado   100  27.157  43.202   26.888
# 38  carga de trabajo y el escaso tiempo   100  12.425  31.689   39.563
# 39      acceder a ayudas o subvenciones   100  20.418  38.416   28.291
#
#      mucho   año  numero_motivo
# 0   13.271  2019              1
# 1   10.553  2019              2
# 2    1.579  2019              3
# 3     6.24  2019              4
# 4   13.061  2019              5
# 5    3.266  2019              6
# 6   20.995  2019              7
# 7   15.156  2019              8
# 8   15.364  2020              1
# 9    9.109  2020              2
# 10   1.836  2020              3
# 11   6.978  2020              4
# 12  10.244  2020              5
# 13   2.578  2020              6
# 14  13.405  2020              7
# 15  11.656  2020              8
# 16  17.067  2021              1
# 17  11.764  2021              2
# 18   1.825  2021              3
# 19   5.935  2021              4
# 20  10.191  2021              5
# 21   3.058  2021              6
# 22  13.566  2021              7
# 23  10.687  2021              8
# 24  15.853  2022              1
# 25  11.605  2022              2
# 26   2.268  2022              3
# 27   6.107  2022              4
# 28  11.783  2022              5
# 29   2.386  2022              6
# 30  14.565  2022              7
# 31  12.499  2022              8
# 32  17.398  2023              1
# 33  11.781  2023              2
# 34   2.025  2023              3
# 35    6.28  2023              4
# 36  11.415  2023              5
# 37   2.753  2023              6
# 38  16.323  2023              7
# 39  12.876  2023              8

# %%
# Verifica si hay filas duplicadas en df_final
duplicados = df_final.duplicated()
print(f"Número de filas duplicadas: {duplicados.sum()}")

# Si quieres ver las filas duplicadas:
df_duplicados = df_final[df_final.duplicated(keep=False)]
print(df_duplicados)
# Out:
# Número de filas duplicadas: 0
# Empty DataFrame
# Columns: [motivo, total, nada, poco, bastante, mucho, año, numero_motivo]
# Index: []

# %%
# Cambiar el tipo de dato de las columnas 'nada' y 'poco' a float
df_final['nada'] = pd.to_numeric(df_final['nada'], errors='coerce')
df_final['poco'] = pd.to_numeric(df_final['poco'], errors='coerce')
df_final['mucho'] = pd.to_numeric(df_final['mucho'], errors='coerce')
df_final['bastante'] = pd.to_numeric(df_final['bastante'], errors='coerce')

# Cambiar el tipo de dato de las columnas 'año' y 'total' a int
df_final['año'] = pd.to_numeric(df_final['año'], errors='coerce').astype('Int64')
df_final['total'] = pd.to_numeric(df_final['total'], errors='coerce').astype('Int64')

df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   motivo         40 non-null     object
#  1   total          40 non-null     Int64
#  2   nada           40 non-null     float64
#  3   poco           40 non-null     float64
#  4   bastante       40 non-null     float64
#  5   mucho          40 non-null     float64
#  6   año            40 non-null     Int64
#  7   numero_motivo  40 non-null     int64
# dtypes: Int64(2), float64(4), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
# Crear una lista para almacenar los resultados
resultados = []

for año in sorted(df_final['año'].unique()):
    df_año = df_final[df_final['año'] == año]
    motivo_top = df_año.loc[df_año['mucho'].idxmax()]
    resultados.append({
        'año': año,
        'numero_motivo': motivo_top['numero_motivo'],
        'mucho': motivo_top['mucho']
    })

# Convertir a DataFrame
df_resultados = pd.DataFrame(resultados)

# Gráfico de barras
plt.figure(figsize=(10,6))
plt.bar(df_resultados['año'], df_resultados['mucho'], color='skyblue')
plt.xticks(df_resultados['año'])
plt.xlabel('Año')
plt.ylabel('Porcentaje "MUCHO"')
plt.title('Motivo con más respuestas "MUCHO" por año')
for i, row in df_resultados.iterrows():
    plt.text(row['año'], row['mucho']+0.5, row['numero_motivo'], rotation=90, va='bottom', ha='center', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### El nivel de formación de los empleados era el apropiado para las necesidades de la empresa

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Busca la(s) fila(s) que contienen exactamente ese texto en la columna 'motivo'
filtro = df_final['motivo'] == "nivel formación apropiado"
df_formacion_apropiada = df_final[filtro].copy()

# Si quieres resetear el índice:
df_formacion_apropiada.reset_index(drop=True, inplace=True)

# Mostrar el resultado
# print(df_formacion_apropiada)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_formacion_apropiada.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('Nivel de formación de los empleados (respuestas)')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_formacion_apropiada[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('Nivel de formación de los empleados - apropiado por año', fontsize=20)
plt.xlabel('Respuesta', fontsize=14)
plt.ylabel('Porcentaje', fontsize=14)
plt.legend(title='Año', fontsize=12, title_fontsize='13')
plt.show()

# %% [markdown]
# ### La estrategia preferida de la empresa fue contratar personal con la cualificación, habilidades o competencias requeridas

# %%
# Busca las filas que contienen exactamente cualquiera de los dos textos en la columna 'motivo'
filtro = df_final['motivo'] == "contratar personal cualificado"
df_estrategia_preferida = df_final[filtro].copy()

# Si quieres resetear el índice:
df_estrategia_preferida.reset_index(drop=True, inplace=True)

# Mostrar el resultado
print(df_estrategia_preferida)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_estrategia_preferida.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('Nivel de formación de los empleados (respuestas)')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_estrategia_preferida[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('Nivel de formación de los empleados por año')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.legend(title='Año')
plt.show()
# Out:
#                            motivo  total    nada    poco  bastante   mucho  \
# 0  contratar personal cualificado    100  24.645  29.041    35.761  10.553
# 1  contratar personal cualificado    100  34.293  20.911    35.687   9.109
# 2  contratar personal cualificado    100  22.605  28.778    36.853  11.764
# 3  contratar personal cualificado    100  17.780  27.601    43.014  11.605
# 4  contratar personal cualificado    100  20.622  25.614    41.983  11.781
#
#     año  numero_motivo
# 0  2019              2
# 1  2020              2
# 2  2021              2
# 3  2022              2
# 4  2023              2

# %% [markdown]
# ### Dificultad para evaluar la necesidades de formación de la empresa

# %%
# Busca la(s) fila(s) que contienen exactamente ese texto en la columna 'motivo'
filtro = df_final['motivo'] == "evaluar necesidades"
df_dificultad_evaluar = df_final[filtro].copy()

# Si quieres resetear el índice:
df_dificultad_evaluar.reset_index(drop=True, inplace=True)

# Mostrar el resultado
# print(df_dificultad_evaluar)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_dificultad_evaluar.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('Dificultad para evaluar la necesidades')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_dificultad_evaluar[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('Dificultad para evaluar la necesidades por año')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.legend(title='Año')
plt.show()

# %% [markdown]
# ### La falta de cursos de formación adecuados en el mercado

# %%
# Busca la(s) fila(s) que contienen exactamente ese texto en la columna 'motivo'
filtro = df_final['motivo'] == "falta de cursos adecuados"
df_falta_cursos = df_final[filtro].copy()

# Si quieres resetear el índice:
df_falta_cursos.reset_index(drop=True, inplace=True)

# Mostrar el resultado
# print(df_falta_cursos)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_falta_cursos.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('Falta de cursos de formación adecuados en el mercado')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_falta_cursos[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('Falta de cursos de formación adecuados en el mercado por año')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.legend(title='Año')
plt.show()

# %% [markdown]
# ### El alto coste de los cursos de formación

# %%
# Busca la(s) fila(s) que contienen exactamente ese texto en la columna 'motivo'
filtro = df_final['motivo'] == "alto coste cursos"
df_alto_coste = df_final[filtro].copy()

# Si quieres resetear el índice:
df_alto_coste.reset_index(drop=True, inplace=True)

# Mostrar el resultado
# print(df_alto_coste)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_alto_coste.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('El alto coste de los cursos de formación')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_alto_coste[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('El alto coste de los cursos de formación por año')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.legend(title='Año')
plt.show()

# %% [markdown]
# ### El mayor esfuerzo realizado en años anteriores para ofrecer formación a sus trabajadores

# %%
# Busca la(s) fila(s) que contienen exactamente ese texto en la columna 'motivo'
filtro = df_final['motivo'] == "esfuerzo realizado"
df_esfuerzo_realizado = df_final[filtro].copy()

# Si quieres resetear el índice:
df_esfuerzo_realizado.reset_index(drop=True, inplace=True)

# Mostrar el resultado
# print(df_esfuerzo_realizado)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_esfuerzo_realizado.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('El mayor esfuerzo realizado en años anteriores para ofrecer formación a sus trabajadores')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_esfuerzo_realizado[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('El mayor esfuerzo realizado en años anteriores para ofrecer formación a sus trabajadores por año')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.legend(title='Año')
plt.show()

# %% [markdown]
# ### La elevada carga de trabajo y el escaso tiempo disponible de los empleados de su empresa

# %%
# Busca la(s) fila(s) que contienen exactamente ese texto en la columna 'motivo'
filtro = df_final['motivo'] == "carga de trabajo y el escaso tiempo"
df_elevada_carga = df_final[filtro].copy()

# Si quieres resetear el índice:
df_elevada_carga.reset_index(drop=True, inplace=True)

# Mostrar el resultado
# print(df_elevada_carga)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_elevada_carga.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('La elevada carga de trabajo y el escaso tiempo disponible de los empleados de su empresa')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_elevada_carga[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('La elevada carga de trabajo y el escaso tiempo disponible de los empleados de su empresa por año')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.legend(title='Año')
plt.show()

# %% [markdown]
# ### Dificultad para acceder a ayudas o subvenciones públicas

# %%
# Busca la(s) fila(s) que contienen exactamente ese texto en la columna 'motivo'
filtro = df_final['motivo'] == "acceder a ayudas o subvenciones"
df_acceder_ayudas = df_final[filtro].copy()

# Si quieres resetear el índice:
df_acceder_ayudas.reset_index(drop=True, inplace=True)

# Mostrar el resultado
# print(df_acceder_ayudas)

# Selecciona solo las columnas de interés (ajusta si tienes más columnas)
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho']
valores = df_acceder_ayudas.loc[0, columnas_respuestas]

plt.figure(figsize=(8,5))
plt.bar(columnas_respuestas, valores, color='skyblue')
plt.title('Dificultad para acceder a ayudas o subvenciones públicas')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()

# Selecciona solo las columnas de interés y la columna Fuente
columnas_respuestas = ['nada', 'poco', 'bastante', 'mucho', 'año']
df_plot = df_acceder_ayudas[columnas_respuestas].copy()

# Convierte a formato largo para facilitar el gráfico
df_melt = df_plot.melt(id_vars='año', var_name='Respuesta', value_name='Cantidad')

plt.figure(figsize=(10,6))
sns.barplot(data=df_melt, x='Respuesta', y='Cantidad', hue='año')
plt.title('Dificultad para acceder a ayudas o subvenciones públicas por año')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.legend(title='Año')
plt.show()

# %%
# Para cada año, ¿qué motivo tiene más respuestas "mucho"?
for año in sorted(df_final['año'].unique()):
    df_año = df_final[df_final['año'] == año]
    motivo_top = df_año.loc[df_año['mucho'].idxmax()]
    print(f"Año {año}: Barrera más común (MUCHO): {motivo_top['numero_motivo']} ({motivo_top['mucho']})")
# Out:
# Año 2019: Barrera más común (MUCHO): 7 (20.995)
# Año 2020: Barrera más común (MUCHO): 1 (15.364)
# Año 2021: Barrera más común (MUCHO): 1 (17.067)
# Año 2022: Barrera más común (MUCHO): 1 (15.853)
# Año 2023: Barrera más común (MUCHO): 1 (17.398)

# %%
# Crear una lista para almacenar los resultados
resultados = []

for año in sorted(df_final['año'].unique()):
    df_año = df_final[df_final['año'] == año]
    motivo_top = df_año.loc[df_año['mucho'].idxmax()]
    resultados.append({
        'año': año,
        'numero_motivo': motivo_top['numero_motivo'],
        'mucho': motivo_top['mucho']
    })

# Convertir a DataFrame
df_resultados = pd.DataFrame(resultados)

# Gráfico de barras
plt.figure(figsize=(10,6))
plt.bar(df_resultados['año'], df_resultados['mucho'], color='skyblue')
plt.xticks(df_resultados['año'])
plt.xlabel('Año')
plt.ylabel('Porcentaje "MUCHO"')
plt.title('Motivo con más respuestas "MUCHO" por año')
for i, row in df_resultados.iterrows():
    plt.text(row['año'], row['mucho']+0.5, row['numero_motivo'], rotation=90, va='bottom', ha='center', fontsize=8)
plt.tight_layout()
plt.show()

# %%
# Crear una lista para almacenar los resultados
resultados = []

for año in sorted(df_final['año'].unique()):
    df_año = df_final[df_final['año'] == año]
    motivo_top = df_año.loc[df_año['nada'].idxmax()]
    resultados.append({
        'año': año,
        'numero_motivo': motivo_top['numero_motivo'],
        'nada': motivo_top['nada']
    })

# Convertir a DataFrame
df_resultados = pd.DataFrame(resultados)

# Gráfico de barras
plt.figure(figsize=(10,6))
plt.bar(df_resultados['año'], df_resultados['nada'], color='skyblue')
plt.xticks(df_resultados['año'])
plt.xlabel('Año')
plt.ylabel('Porcentaje "nada"')
plt.title('Motivo con más respuestas "nada" por año')
for i, row in df_resultados.iterrows():
    plt.text(row['año'], row['nada']+0.5, row['numero_motivo'], rotation=90, va='bottom', ha='center', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Formato largo

# %%
# Organizar df_final en formato largo con las columnas solicitadas

columnas_largas = ['año', 'motivo', 'numero_motivo', 'nada', 'poco', 'bastante', 'mucho']

# Convierte a formato largo (melt)
df_largo = pd.melt(
    df_final[columnas_largas],
    id_vars=['año', 'motivo', 'numero_motivo'],
    value_vars=['nada', 'poco', 'bastante', 'mucho'],
    var_name='nivel',
    value_name='porcentaje'
)

# Opcional: ordena el DataFrame
df_largo = df_largo.sort_values(['año', 'numero_motivo', 'nivel'])

df_largo.head
# Out:
# <bound method NDFrame.head of       año                               motivo  numero_motivo     nivel  \
# 80   2019            nivel formación apropiado              1  bastante
# 120  2019            nivel formación apropiado              1     mucho
# 0    2019            nivel formación apropiado              1      nada
# 40   2019            nivel formación apropiado              1      poco
# 81   2019       contratar personal cualificado              2  bastante
# ..    ...                                  ...            ...       ...
# 78   2023  carga de trabajo y el escaso tiempo              7      poco
# 119  2023      acceder a ayudas o subvenciones              8  bastante
# 159  2023      acceder a ayudas o subvenciones              8     mucho
# 39   2023      acceder a ayudas o subvenciones              8      nada
# 79   2023      acceder a ayudas o subvenciones              8      poco
#
#      porcentaje
# 80       45.004
# 120      13.271
# 0        13.179
# 40       28.546
# 81       35.761
# ..          ...
# 78       31.689
# 119      28.291
# 159      12.876
# 39       20.418
# 79       38.416
#
# [160 rows x 5 columns]>

# %%
df_largo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 80 to 79
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   año            160 non-null    Int64
#  1   motivo         160 non-null    object
#  2   numero_motivo  160 non-null    int64
#  3   nivel          160 non-null    object
#  4   porcentaje     160 non-null    float64
# dtypes: Int64(1), float64(1), int64(1), object(2)
# memory usage: 7.7+ KB

# %% [markdown]
# ### Visualización de tendencias por motivo
# permitirá ver si alguna barrera está creciendo o disminuyendo en importancia con el tiempo.
#
# * evolución anual para cada motivo, especialmente en las categorías “MUCHO” y “BASTANTE”, ya que reflejan mayor intensidad del obstáculo.

# %%
# Filtrar las categorías más relevantes
df_filtrado = df_largo[df_largo['nivel'].isin(['bastante'])]

# Define los años que quieres mostrar en el eje x
anios_eje_x = [2019, 2020, 2021, 2022, 2023]

# Paleta de colores pastel para mejor contraste
palette = sns.color_palette("Set2", n_colors=df_filtrado['motivo'].nunique())

plt.figure(figsize=(8, 7))
ax = sns.lineplot(
    data=df_filtrado,
    x='año',
    y='porcentaje',
    hue='motivo',
    marker='o',
    palette=palette,
    linewidth=3,
    markersize=10
)

plt.title('Tendencia de Barreras a la Formación (bastante)', fontsize=22, fontweight='bold')
plt.ylabel('Porcentaje', fontsize=18)
plt.xlabel('Año', fontsize=18)
plt.xticks(anios_eje_x, fontsize=15)
plt.yticks(fontsize=15)
plt.ylim(bottom=0)  # El eje Y inicia en 0
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.legend(
    bbox_to_anchor=(1.01, 1),
    loc='upper left',
    borderaxespad=0,
    fontsize=18,  # Tamaño de letra de la leyenda aumentado
    title='Motivos',
    title_fontsize=20,
    frameon=False
)
# Opcional: guardar en alta resolución para PowerPoint
#plt.savefig('grafica_barreras_formativas_mejorada.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Análisis de las barreras más comunes
# visión general de qué barreras son las más comunes en promedio en esos 5 años.
#
# * Calcula el promedio del porcentaje de respuestas "MUCHO" + "BASTANTE" por motivo y año.
# * Ordena los motivos por esos promedios para identificar las más persistentes.

# %%
import numpy as np

# Filtrar solo los niveles "mucho" y "bastante"
df_mb = df_largo[df_largo['nivel'].isin(['mucho', 'bastante'])]

# Sumar "mucho" + "bastante" por motivo y año
df_mb_sum = df_mb.groupby(['motivo', 'año'])['porcentaje'].sum().reset_index()

# Calcular el promedio anual de cada motivo
df_mb_avg = df_mb_sum.groupby('motivo')['porcentaje'].mean().sort_values(ascending=False)

# Redondear hacia arriba al número entero más alto
df_mb_avg = np.ceil(df_mb_avg)

print(df_mb_avg)
# Out:
# motivo
# nivel formación apropiado              71.0
# carga de trabajo y el escaso tiempo    57.0
# contratar personal cualificado         50.0
# alto coste cursos                      43.0
# acceder a ayudas o subvenciones        41.0
# falta de cursos adecuados              29.0
# esfuerzo realizado                     28.0
# evaluar necesidades                    18.0
# Name: porcentaje, dtype: float64

# %%
import matplotlib.pyplot as plt

# Si df_mb_avg es una Series, conviértelo a DataFrame para graficar fácilmente
df_mb_avg_plot = df_mb_avg.reset_index()

plt.figure(figsize=(10, 6))
plt.barh(df_mb_avg_plot['motivo'], df_mb_avg_plot['porcentaje'], color='skyblue')
plt.xlabel('Promedio de Porcentaje (%)', fontsize=14)
plt.ylabel('Motivos', fontsize=14)
plt.title('Promedio de respuestas "MUCHO" + "BASTANTE" por motivo (2019-2023)', fontsize=16, fontweight='bold')
plt.gca().invert_yaxis()  # Motivo más alto arriba
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt

# Convertir a DataFrame si es Series
df_mb_avg_plot = df_mb_avg.reset_index()

# Definir colores por grupo (3 primeras: azul fuerte, siguientes 2: azul medio, últimas 3: azul claro)
colors = ['#005B96'] * 3 + ['#3399FF'] * 2 + ['#B3D9FF'] * 3

plt.figure(figsize=(10, 6))
bars = plt.barh(df_mb_avg_plot['motivo'], df_mb_avg_plot['porcentaje'], color=colors)

# Etiquetas y título
plt.xlabel('Promedio de Porcentaje (%)', fontsize=14)
plt.ylabel('Motivos', fontsize=14)
plt.title('Promedio de respuestas "MUCHO" + "BASTANTE" por motivo (2019–2023)', fontsize=20, fontweight='bold')

# Aumentar tamaño de fuente en eje Y (motivos)
plt.yticks(fontsize=14)

# Motivo más alto arriba
plt.gca().invert_yaxis()

# Líneas de guía horizontales
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de tendencia (estadístico)
# Para detectar tendencias significativas en el tiempo:

# %%
from scipy.stats import linregress

tendencias = []
for motivo in df_filtrado['motivo'].unique():
    sub = df_filtrado[(df_filtrado['motivo'] == motivo) & (df_filtrado['nivel'] == 'mucho')]
    res = linregress(sub['año'], sub['porcentaje'])
    tendencias.append((motivo, res.slope, res.pvalue))

tendencias_df = pd.DataFrame(tendencias, columns=['motivo', 'pendiente', 'p-valor'])
tendencias_df = tendencias_df.sort_values(by='pendiente', ascending=False)
print(tendencias_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20052\2903984301.py in ?()
#       2
#       3 tendencias = []
#       4 for motivo in df_filtrado['motivo'].unique():
#       5     sub = df_filtrado[(df_filtrado['motivo'] == motivo) & (df_filtrado['nivel'] == 'mucho')]
# ----> 6     res = linregress(sub['año'], sub['porcentaje'])
#       7     tendencias.append((motivo, res.slope, res.pvalue))
#       8
#       9 tendencias_df = pd.DataFrame(tendencias, columns=['motivo', 'pendiente', 'p-valor'])
#
# c:\Users\maili\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py in ?(x, y, alternative)
#   10698         x = np.asarray(x)
#   10699         y = np.asarray(y)
#   10700
#   10701     if x.size == 0 or y.size == 0:
# > 10702         raise ValueError("Inputs must not be empty.")
#   10703
#   10704     if np.amax(x) == np.amin(x) and len(x) > 1:
#   10705         raise ValueError("Cannot calculate a linear regression "
#
# ValueError: Inputs must not be empty.
